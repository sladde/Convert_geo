# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('inspection_locations.csv')
# Out:
#         location_city                                      location_name  \
# 0             Lansing                             Denny's Auto Diagnosis
# 1           Riverdale                                 Elks - Hyattsville
# 2        Grand Rapids                              Jack's Service Center
# 3               Tampa                                Pep Boys - Gunn Hwy
# 4             Kingman                                Midtown Auto Center
# 5            El Cajon                                  Pep Boys El Cajon
# 6          Alexandria                       Wiygul Automotive - Lane Dr.
# 7        Apple Valley                                 Midas Apple Valley
# 8              Clovis                                Jiffy Lube - Fresno
# 9          GREENVILLE   National Tire & Battery Greenville - Chalmers Rd
# 10          Elk Grove                               Elk Grove - Goodyear
# 11          Inglewood                                Pep Boys Spruce Ave
# ...

# %%
g_key = 'AIzaSyB-ABrnkVJO_0Hrm25D4nOh7GtK30WoT7A'
